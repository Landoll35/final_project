# %%
#Import dependency
import pandas as pd

# %%
#Read in CSV
con_pd = pd.read_csv("International_energy_consumption.csv")
con_pd
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Report generated on: 03-15-2023 19:45:45
# ...
