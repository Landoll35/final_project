# %%
#Import dependency
import pandas as pd

# %%
#Read in CSV
prod_pd = pd.read_csv("International_energy_production.csv")
prod_pd
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Report generated on: 03-15-2023 19:46:34
# ...
