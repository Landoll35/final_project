# %%
#Import dependency
import pandas as pd

# %%
#Read in CSV
df = pd.read_csv("Consumption.csv")
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Report generated on: 03-29-2023 20:36:07
# ...

# %%
df = df.reset_index(drop=False)
df
# Out:
#                      level_0                              level_1  \
# 0                        API                                  NaN
# 1                        NaN  total energy consumption (quad Btu)
# 2      INTL.44-2-WORL-QBTU.A                                World
# 3       INTL.44-2-AFG-QBTU.A                          Afghanistan
# 4       INTL.44-2-ALB-QBTU.A                              Albania
# ...                      ...                                  ...
# 1620  INTL.4418-2-WAK-QBTU.A                          Wake Island
# 1621  INTL.4418-2-ESH-QBTU.A                       Western Sahara
# 1622  INTL.4418-2-YEM-QBTU.A                                Yemen
# 1623  INTL.4418-2-ZMB-QBTU.A                               Zambia
# 1624  INTL.4418-2-ZWE-QBTU.A                             Zimbabwe
#
#                    level_2               level_3               level_4  \
# 0                     1980                  1981                  1982
# ...

# %%
df.columns=df.iloc[0]
df
# Out:
# 0                        API                                  NaN  \
# 0                        API                                  NaN
# 1                        NaN  total energy consumption (quad Btu)
# 2      INTL.44-2-WORL-QBTU.A                                World
# 3       INTL.44-2-AFG-QBTU.A                          Afghanistan
# 4       INTL.44-2-ALB-QBTU.A                              Albania
# ...                      ...                                  ...
# 1620  INTL.4418-2-WAK-QBTU.A                          Wake Island
# 1621  INTL.4418-2-ESH-QBTU.A                       Western Sahara
# 1622  INTL.4418-2-YEM-QBTU.A                                Yemen
# 1623  INTL.4418-2-ZMB-QBTU.A                               Zambia
# 1624  INTL.4418-2-ZWE-QBTU.A                             Zimbabwe
#
# 0                     1980                  1981                  1982  \
# 0                     1980                  1981                  1982
# ...

# %%
df = df.dropna(subset=['API'])
df = df.drop(index=0)
df
# Out:
# 0                        API                     NaN                  1980  \
# 2      INTL.44-2-WORL-QBTU.A                   World    292.93991538631695
# 3       INTL.44-2-AFG-QBTU.A             Afghanistan   0.02658321667756184
# 4       INTL.44-2-ALB-QBTU.A                 Albania   0.16298182182124926
# 5       INTL.44-2-DZA-QBTU.A                 Algeria    0.7806951671133022
# 6       INTL.44-2-ASM-QBTU.A          American Samoa          0.0058931124
# ...                      ...                     ...                   ...
# 1620  INTL.4418-2-WAK-QBTU.A             Wake Island                     0
# 1621  INTL.4418-2-ESH-QBTU.A          Western Sahara                     0
# 1622  INTL.4418-2-YEM-QBTU.A                   Yemen                     0
# 1623  INTL.4418-2-ZMB-QBTU.A                  Zambia       0.0842504416429
# 1624  INTL.4418-2-ZWE-QBTU.A                Zimbabwe  0.048444954208071205
#
# ...

# %%
split = df['API'].str.split("-").str[0]
split
df['Energy Type'] = split

# %%
df
# Out:
# 0                        API                     NaN                  1980  \
# 2      INTL.44-2-WORL-QBTU.A                   World    292.93991538631695
# 3       INTL.44-2-AFG-QBTU.A             Afghanistan   0.02658321667756184
# 4       INTL.44-2-ALB-QBTU.A                 Albania   0.16298182182124926
# 5       INTL.44-2-DZA-QBTU.A                 Algeria    0.7806951671133022
# 6       INTL.44-2-ASM-QBTU.A          American Samoa          0.0058931124
# ...                      ...                     ...                   ...
# 1620  INTL.4418-2-WAK-QBTU.A             Wake Island                     0
# 1621  INTL.4418-2-ESH-QBTU.A          Western Sahara                     0
# 1622  INTL.4418-2-YEM-QBTU.A                   Yemen                     0
# 1623  INTL.4418-2-ZMB-QBTU.A                  Zambia       0.0842504416429
# 1624  INTL.4418-2-ZWE-QBTU.A                Zimbabwe  0.048444954208071205
#
# ...

# %%
df['Energy Type'] = df['Energy Type'].str.replace('INTL.4411', 'Coal')
df['Energy Type'] = df['Energy Type'].str.replace('INTL.4413', 'Natural Gas')
df['Energy Type'] = df['Energy Type'].str.replace('INTL.4415', 'Petroleum')
df['Energy Type'] = df['Energy Type'].str.replace('INTL.4419', 'Nuclear, Renewables and Other')
df['Energy Type'] = df['Energy Type'].str.replace('INTL.4417', 'Nuclear')
df['Energy Type'] = df['Energy Type'].str.replace('INTL.4418', 'Renewables')
df['Energy Type'] = df['Energy Type'].str.replace('INTL.44', 'Total Energy Production')
# Out:
# C:\Users\calyd\AppData\Local\Temp\ipykernel_10004\1983646703.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Energy Type'] = df['Energy Type'].str.replace('INTL.4411', 'Coal')
# C:\Users\calyd\AppData\Local\Temp\ipykernel_10004\1983646703.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Energy Type'] = df['Energy Type'].str.replace('INTL.4413', 'Natural Gas')
# C:\Users\calyd\AppData\Local\Temp\ipykernel_10004\1983646703.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Energy Type'] = df['Energy Type'].str.replace('INTL.4415', 'Petroleum')
# C:\Users\calyd\AppData\Local\Temp\ipykernel_10004\1983646703.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Energy Type'] = df['Energy Type'].str.replace('INTL.4419', 'Nuclear, Renewables and Other')
# ...

# %%
df
# Out:
# 0                        API                     NaN                  1980  \
# 2      INTL.44-2-WORL-QBTU.A                   World    292.93991538631695
# 3       INTL.44-2-AFG-QBTU.A             Afghanistan   0.02658321667756184
# 4       INTL.44-2-ALB-QBTU.A                 Albania   0.16298182182124926
# 5       INTL.44-2-DZA-QBTU.A                 Algeria    0.7806951671133022
# 6       INTL.44-2-ASM-QBTU.A          American Samoa          0.0058931124
# ...                      ...                     ...                   ...
# 1620  INTL.4418-2-WAK-QBTU.A             Wake Island                     0
# 1621  INTL.4418-2-ESH-QBTU.A          Western Sahara                     0
# 1622  INTL.4418-2-YEM-QBTU.A                   Yemen                     0
# 1623  INTL.4418-2-ZMB-QBTU.A                  Zambia       0.0842504416429
# 1624  INTL.4418-2-ZWE-QBTU.A                Zimbabwe  0.048444954208071205
#
# ...

# %%
df = df.replace('--', '0.0')
df = df.replace('ie', '0.0')
df
# Out:
# 0                        API                     NaN                  1980  \
# 2      INTL.44-2-WORL-QBTU.A                   World    292.93991538631695
# 3       INTL.44-2-AFG-QBTU.A             Afghanistan   0.02658321667756184
# 4       INTL.44-2-ALB-QBTU.A                 Albania   0.16298182182124926
# 5       INTL.44-2-DZA-QBTU.A                 Algeria    0.7806951671133022
# 6       INTL.44-2-ASM-QBTU.A          American Samoa          0.0058931124
# ...                      ...                     ...                   ...
# 1620  INTL.4418-2-WAK-QBTU.A             Wake Island                     0
# 1621  INTL.4418-2-ESH-QBTU.A          Western Sahara                     0
# 1622  INTL.4418-2-YEM-QBTU.A                   Yemen                     0
# 1623  INTL.4418-2-ZMB-QBTU.A                  Zambia       0.0842504416429
# 1624  INTL.4418-2-ZWE-QBTU.A                Zimbabwe  0.048444954208071205
#
# ...

# %%
df['1980'] = df['1980'].astype(float)
df['1981'] = df['1981'].astype(float)
df['1982'] = df['1982'].astype(float)
df['1983'] = df['1983'].astype(float)
df['1984'] = df['1984'].astype(float)
df['1985'] = df['1985'].astype(float)
df['1986'] = df['1986'].astype(float)
df['1987'] = df['1987'].astype(float)
df['1988'] = df['1988'].astype(float)
df['1989'] = df['1989'].astype(float)

# %%
df['1990'] = df['1990'].astype(float)
df['1991'] = df['1991'].astype(float)
df['1992'] = df['1992'].astype(float)
df['1993'] = df['1993'].astype(float)
df['1994'] = df['1994'].astype(float)
df['1995'] = df['1995'].astype(float)
df['1996'] = df['1996'].astype(float)
df['1997'] = df['1997'].astype(float)
df['1998'] = df['1998'].astype(float)
df['1999'] = df['1999'].astype(float)

# %%
df['2000'] = df['2000'].astype(float)
df['2001'] = df['2001'].astype(float)
df['2002'] = df['2002'].astype(float)
df['2003'] = df['2003'].astype(float)
df['2004'] = df['2004'].astype(float)
df['2005'] = df['2005'].astype(float)
df['2006'] = df['2006'].astype(float)
df['2007'] = df['2007'].astype(float)
df['2008'] = df['2008'].astype(float)
df['2009'] = df['2009'].astype(float)

# %%
df['2010'] = df['2010'].astype(float)
df['2011'] = df['2011'].astype(float)
df['2012'] = df['2012'].astype(float)
df['2013'] = df['2013'].astype(float)
df['2014'] = df['2014'].astype(float)
df['2015'] = df['2015'].astype(float)
df['2016'] = df['2016'].astype(float)
df['2017'] = df['2017'].astype(float)
df['2018'] = df['2018'].astype(float)
df['2019'] = df['2019'].astype(float)

# %%
df['2020'] = df['2020'].astype(float)
df['2021'] = df['2021'].astype(float)

# %%
df.dtypes
# Out:
# 0
# API             object
# NaN             object
# 1980           float64
# 1981           float64
# 1982           float64
# 1983           float64
# 1984           float64
# 1985           float64
# 1986           float64
# 1987           float64
# 1988           float64
# 1989           float64
# 1990           float64
# 1991           float64
# 1992           float64
# 1993           float64
# 1994           float64
# 1995           float64
# 1996           float64
# 1997           float64
# 1998           float64
# 1999           float64
# 2000           float64
# 2001           float64
# 2002           float64
# 2003           float64
# 2004           float64
# 2005           float64
# 2006           float64
# 2007           float64
# 2008           float64
# 2009           float64
# 2010           float64
# 2011           float64
# 2012           float64
# 2013           float64
# 2014           float64
# 2015           float64
# 2016           float64
# ...
