# %%
#Import dependency
import pandas as pd
import re
import numpy as np

# %%
#Read in CSV
con_pd = pd.read_csv("International_energy_consumption.csv")
con_pd
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Report generated on: 03-15-2023 19:45:45
# ...

# %%
con_pd.dtypes
# Out:
# Report generated on: 03-15-2023 19:45:45    object
# dtype: object

# %%
clean_con_df = con_pd.replace('--', '0.0')
clean_con_df = clean_con_df.replace('ie', '0.0')
clean_con_df.head(15)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Report generated on: 03-15-2023 
# ...
