# %%
#Import dependency
import pandas as pd

# %%
#Read in CSV
df = pd.read_csv("Consumption.csv")
df.head(20)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Report generated on: 03-29-2023 20:36:07
# ...

# %%
df = df.reset_index(drop=False)

# %%
df.head(15)
# Out:
#                   level_0                              level_1  \
# 0                     API                                  NaN
# 1                     NaN  total energy consumption (quad Btu)
# 2   INTL.44-2-WORL-QBTU.A                                World
# 3    INTL.44-2-AFG-QBTU.A                          Afghanistan
# 4    INTL.44-2-ALB-QBTU.A                              Albania
# 5    INTL.44-2-DZA-QBTU.A                              Algeria
# 6    INTL.44-2-ASM-QBTU.A                       American Samoa
# 7    INTL.44-2-AGO-QBTU.A                               Angola
# 8    INTL.44-2-ATA-QBTU.A                           Antarctica
# 9    INTL.44-2-ATG-QBTU.A                  Antigua and Barbuda
# 10   INTL.44-2-ARG-QBTU.A                            Argentina
# 11   INTL.44-2-ARM-QBTU.A                              Armenia
# 12   INTL.44-2-ABW-QBTU.A                                Aruba
# 13   INTL.44-2-AUS-QBTU.A                            Australia
# ...
