# %%
#Import dependency
import pandas as pd
import re
import numpy as np

# %%
#Read in CSV
con_pd = pd.read_csv("International_energy_consumption.csv")
con_pd
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Report generated on: 03-15-2023 19:45:45
# ...

# %%
df = con_df.reset_index(drop=False)
df
# Out:
#                       level_0  \
# 0                         API
# 1                         NaN
# 2       INTL.44-2-WORL-QBTU.A
# 3     INTL.4411-2-WORL-QBTU.A
# 4     INTL.4413-2-WORL-QBTU.A
# ...                       ...
# 1844   INTL.4413-2-ZWE-QBTU.A
# 1845   INTL.4415-2-ZWE-QBTU.A
# 1846   INTL.4419-2-ZWE-QBTU.A
# 1847                     none
# 1848   INTL.4418-2-ZWE-QBTU.A
#
#                                                 level_1               level_2  \
# 0                                                   NaN                  1980
# 1                                                 World                   NaN
# 2                                Consumption (quad Btu)    292.93991538631695
# 3                                       Coal (quad Btu)     78.69456099624699
# 4                                Natural gas (quad Btu)          53.865223303
# ...                                                 ...                   ...
# ...

# %%
df.dtypes
# Out:
# level_0                                     object
# level_1                                     object
# level_2                                     object
# level_3                                     object
# level_4                                     object
# level_5                                     object
# level_6                                     object
# level_7                                     object
# level_8                                     object
# level_9                                     object
# level_10                                    object
# level_11                                    object
# level_12                                    object
# level_13                                    object
# level_14                                    object
# level_15                                    object
# level_16                                    object
# level_17                                    object
# ...

# %%
df = df.replace('--', '0.0')
df = df.replace('ie', '0.0')
df
# Out:
#                       level_0  \
# 0                         API
# 1                         NaN
# 2       INTL.44-2-WORL-QBTU.A
# 3     INTL.4411-2-WORL-QBTU.A
# 4     INTL.4413-2-WORL-QBTU.A
# ...                       ...
# 1844   INTL.4413-2-ZWE-QBTU.A
# 1845   INTL.4415-2-ZWE-QBTU.A
# 1846   INTL.4419-2-ZWE-QBTU.A
# 1847                     none
# 1848   INTL.4418-2-ZWE-QBTU.A
#
#                                                 level_1               level_2  \
# 0                                                   NaN                  1980
# 1                                                 World                   NaN
# 2                                Consumption (quad Btu)    292.93991538631695
# 3                                       Coal (quad Btu)     78.69456099624699
# 4                                Natural gas (quad Btu)          53.865223303
# ...                                                 ...                   ...
# ...

# %%
df = df.rename(columns={'level_0':'API'})
df
# Out:
#                           API  \
# 0                         API
# 1                         NaN
# 2       INTL.44-2-WORL-QBTU.A
# 3     INTL.4411-2-WORL-QBTU.A
# 4     INTL.4413-2-WORL-QBTU.A
# ...                       ...
# 1844   INTL.4413-2-ZWE-QBTU.A
# 1845   INTL.4415-2-ZWE-QBTU.A
# 1846   INTL.4419-2-ZWE-QBTU.A
# 1847                     none
# 1848   INTL.4418-2-ZWE-QBTU.A
#
#                                                 level_1               level_2  \
# 0                                                   NaN                  1980
# 1                                                 World                   NaN
# 2                                Consumption (quad Btu)    292.93991538631695
# 3                                       Coal (quad Btu)     78.69456099624699
# 4                                Natural gas (quad Btu)          53.865223303
# ...                                                 ...                   ...
# ...
