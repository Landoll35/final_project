# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
renew1_df = pd.read_csv("2011_Renewable_GDP.csv")
renew1_df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  2011_renew      2011_gdp
# 0             0    0.005784  1.819041e+10
# 1             1    0.039753  1.289076e+10
# 2             2    0.004830  2.000131e+11
# 3             3    0.000000  5.700000e+08
# 4             4    0.038650  1.094366e+11
# ..          ...         ...           ...
# 198         225    0.000000  7.737746e+09
# 199         226    0.000000  6.804560e+11
# 200         227    0.000019  3.272642e+10
# 201         228    0.111087  2.345952e+10
# 202         229    0.051304  1.410192e+10
#
# [203 rows x 3 columns]>

# %%
plt.scatter(renew1_df['2011_gdp'], renew1_df['2011_renew'])
plt.xlabel('GDP')
plt.ylabel('Energy Production')
plt.show()

# %%
X = renew1_df['2011_gdp'].values.reshape(-1, 1)

# %%
X.shape
# Out:
# (203, 1)

# %%
y = renew1_df['2011_renew']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (203,)

# %%
plt.scatter(renew1_df['2011_gdp'], renew1_df['2011_renew'])
plt.xlabel('GDP')
plt.ylabel('Energy Production')
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [5.99898815e-13]
# 0.0016537715758304927

# %%
from sklearn.model_selection import train_test_split

# %%
X = renew1_df[['2011_gdp']]
Y = renew1_df[['2011_renew']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.2)

# %%
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([[ 1.31664872e-02],
#        [ 5.06087740e-03],
#        [-1.09400086e-02],
#        [ 9.20862495e-03],
#        [ 6.70919270e-01],
#        [-1.04664587e-02],
#        [ 3.97206351e-03],
#        [-9.23071766e-03],
#        [-1.20194811e-02],
#        [-1.61482159e-03],
#        [-2.96250277e-03],
#        [ 1.41031629e-03],
#        [ 7.00971871e-02],
#        [-4.59731420e-03],
#        [ 4.89263415e-03],
#        [-3.27760493e-03],
#        [ 5.04582449e-01],
#        [ 2.61349608e-02],
#        [ 1.50150968e+00],
#        [-5.33650372e-03],
#        [ 1.24505646e-01],
#        [-1.19968056e-02],
#        [-8.09413254e-03],
#        [ 1.03692393e-01],
#        [ 3.87504196e-03],
#        [ 5.12919384e-02],
#        [-8.43036966e-03],
#        [ 2.76248259e-01],
#        [-8.10599310e-03],
#        [ 3.36204574e-04],
#        [-1.20194811e-02],
#        [-1.13613334e-02],
#        [ 9.54407148e-02],
#        [ 4.02137274e-01],
#        [-5.94810920e-03],
# ...

# %%
clf.score(x_test,y_test)
# Out:
# 0.5060528173913784
