# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
renew1_df = pd.read_csv("2021_Renewable_GDP1.csv")
renew1_df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  2021_renew      2021_gdp
# 0             0    0.006114  1.478686e+10
# 1             1    0.078632  1.825579e+10
# 2             2    0.007956  1.630444e+11
# 3             3    0.000044  7.090000e+08
# 4             4    0.102802  6.740429e+10
# ..          ...         ...           ...
# 198         225    0.000000  9.481916e+09
# 199         226    0.000000  8.401873e+11
# 200         227    0.005244  0.000000e+00
# 201         228    0.142991  2.214763e+10
# 202         229    0.036331  2.837124e+10
#
# [203 rows x 3 columns]>

# %%
plt.scatter(renew1_df['2021_gdp'], renew1_df['2021_renew'])
plt.xlabel('GDP')
plt.ylabel('Energy Production')
plt.show()

# %%
X = renew1_df['2021_gdp'].values.reshape(-1, 1)

# %%
X.shape
# Out:
# (203, 1)

# %%
y = renew1_df['2021_renew']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (203,)

# %%
plt.scatter(renew1_df['2021_gdp'], renew1_df['2021_renew'])
plt.xlabel('GDP')
plt.ylabel('Energy Production')
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [7.32339512e-13]
# -0.01048212975522883

# %%
from sklearn.model_selection import train_test_split

# %%
X = renew1_df[['2021_gdp']]
Y = renew1_df[['2021_renew']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.2)
# print the data
x_train
# Out:
#          2021_gdp
# 65   2.957880e+12
# 38   1.773406e+13
# 133  1.491500e+10
# 128  1.012847e+12
# 157  8.335412e+11
# ..            ...
# 134  4.408336e+11
# 188  4.052979e+10
# 116  9.996250e+09
# 4    6.740429e+10
# 148  1.796772e+11
#
# [162 rows x 1 columns]

# %%
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([[-0.02782369],
#        [ 0.88813019],
#        [-0.03673886],
#        [-0.03673886],
#        [-0.03608186],
#        [-0.02779375],
#        [-0.03635618],
#        [-0.02428104],
#        [ 2.27121701],
#        [-0.03550995],
#        [-0.00562688],
#        [ 0.00996997],
#        [ 0.01282046],
#        [ 0.02574001],
#        [-0.03673886],
#        [-0.03673886],
#        [-0.03673886],
#        [ 0.39494843],
#        [ 0.03174021],
#        [ 0.17928629],
#        [ 1.25575813],
#        [ 0.23427613],
#        [ 1.4080238 ],
#        [-0.03673886],
#        [-0.03673886],
#        [ 0.31728971],
#        [-0.03566991],
#        [-0.02942083],
#        [ 0.02787737],
#        [ 0.06707051],
#        [-0.03329226],
#        [ 0.01357143],
#        [-0.03673886],
#        [-0.02669332],
#        [-0.03418915],
#        [-0.01813566],
#        [-0.02656142],
#        [-0.03644529],
#        [ 0.42514644],
#        [-0.0281793 ],
#        [-0.0266669 ]])

# %%
clf.score(x_test,y_test)
# Out:
# 0.7069750462422917
