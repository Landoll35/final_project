# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
renew1_df = pd.read_csv("2001_Renewable_GDP.csv")
renew1_df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  2001_renew  2001_gdp
# 0             0    0.005146  0.005146
# 1             1    0.036362  0.036362
# 2             2    0.000703  0.000703
# 3             3    0.000000  0.000000
# 4             4    0.010405  0.010405
# ..          ...         ...       ...
# 225         225    0.000000  0.000000
# 226         226    0.000000  0.000000
# 227         227    0.000000  0.000000
# 228         228    0.081145  0.081145
# 229         229    0.030668  0.030668
#
# [230 rows x 3 columns]>

# %%
plt.scatter(renew1_df['2001_gdp'], renew1_df['2001_renew'])
plt.xlabel('GDP')
plt.ylabel('Energy Production')
plt.show()

# %%
X = renew1_df['2001_gdp'].values.reshape(-1, 1)

# %%
X.shape
# Out:
# (230, 1)

# %%
y = renew1_df['2001_renew']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (230,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [1.]
# 2.7755575615628914e-17

# %%
print(accuracy_score([1, 1, 0], [1, 0, 1]))
# Out:
# 0.3333333333333333
