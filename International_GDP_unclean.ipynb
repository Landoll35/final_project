# %%
import pandas as pd

# %%
file = "InternationalGDPv1.xlsx"

# %%
df = pd.read_excel(file)

# %%
df.head()
# Out:
#              Afghanistan          Albania           Algeria American Samoa  \
# 0  1980  3,641,723,322.0               ..  42,346,380,830.8             ..
# 1  1981  3,478,787,909.1               ..  44,348,672,667.9             ..
# 2  1982               ..               ..  45,207,088,715.6             ..
# 3  1983               ..               ..  48,801,369,800.4             ..
# 4  1984               ..  1,857,338,011.9  53,698,278,906.0             ..
#
#    Unnamed: 5        Andorra           Angola Antigua and Barbuda  \
# 0         NaN  446,416,105.8  5,930,503,401.0       131,431,026.7
# 1         NaN  388,958,731.3  5,550,483,036.0       147,841,734.4
# 2         NaN  375,895,956.4  5,550,483,036.0       164,369,278.9
# 3         NaN  327,861,832.9  5,784,341,596.4       182,144,093.0
# 4         NaN  330,070,689.3  6,131,475,065.2       208,372,846.3
#
#            Argentina  ... Post-demographic dividend Pre-demographic dividend  \
# ...
